# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8, random_state=105)

# %%
data[0].shape
# Out:
# (200, 2)

# %%
plt.scatter(data[0][:,0],data[0][0:,1],c=data[1])

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.88698081, -8.87574713],
#        [-8.86842188, -2.86434585],
#        [-4.28240566, -9.24210336],
#        [ 7.59945198, -7.50735577]])

# %%
kmeans.labels_
# Out:
# array([2, 2, 1, 3, 3, 3, 1, 2, 0, 0, 0, 2, 1, 1, 3, 3, 0, 2, 2, 0, 0, 2,
#        1, 0, 1, 2, 0, 2, 1, 2, 3, 0, 1, 2, 3, 2, 3, 2, 3, 0, 2, 0, 3, 2,
#        1, 0, 3, 0, 3, 0, 3, 0, 1, 1, 0, 3, 3, 2, 0, 2, 0, 2, 3, 1, 3, 0,
#        0, 1, 2, 0, 2, 3, 0, 3, 1, 3, 0, 2, 2, 0, 2, 2, 3, 3, 3, 2, 1, 3,
#        0, 0, 3, 2, 0, 0, 3, 1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 1, 3, 1, 1, 0,
#        3, 2, 2, 3, 3, 1, 3, 1, 0, 1, 0, 2, 3, 1, 2, 2, 2, 0, 2, 1, 0, 1,
#        2, 1, 2, 1, 1, 1, 0, 3, 1, 0, 1, 2, 3, 2, 1, 0, 1, 1, 2, 2, 3, 1,
#        0, 3, 0, 1, 2, 2, 3, 2, 2, 0, 3, 0, 0, 1, 3, 0, 3, 2, 2, 1, 3, 2,
#        3, 1, 0, 0, 1, 3, 3, 1, 1, 0, 1, 0, 2, 3, 3, 2, 0, 1, 0, 0, 1, 2,
#        3, 0], dtype=int32)

# %%
fig, (ax1,ax2) = plt.subplots(1,2,sharey=True, figsize=(10,6))
ax1.set_title('K means')
ax1.scatter(data[0][:,0], data[0][:,1] , c=kmeans.labels_, cmap='rainbow')

ax2.set_title('K means Org')
ax2.scatter(data[0][:,0], data[0][:,1] , c=data[1], cmap='rainbow')
